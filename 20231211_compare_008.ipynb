# %% [markdown]
# Compare shr all  OOS '2020-10-19'

# %% [markdown]
# ![compare_chart_all_2023-12-11_11-20-06.JPG](attachment:compare_chart_all_2023-12-11_11-20-06.JPG)

# %% [markdown]
# ![compare_shr_all_2023-12-11_11-20-06.JPG](attachment:compare_shr_all_2023-12-11_11-20-06.JPG)

# %% [markdown]
# Comapare OOS WF 1M shr

# %% [markdown]
# ![compare_chart_all_2023-12-11_11-21-11.JPG](attachment:compare_chart_all_2023-12-11_11-21-11.JPG)

# %% [markdown]
# ![compare_shr_all_2023-12-11_11-21-11.JPG](attachment:compare_shr_all_2023-12-11_11-21-11.JPG)

# %% [markdown]
# train oossharpe1 validate oossharpe2 corr feaures removed

# %% [markdown]
# ![Figure_1_trainoossharpe1_validateoossharpe2_corr.png](attachment:Figure_1_trainoossharpe1_validateoossharpe2_corr.png)

# %% [markdown]
# ![Figure_2_trainoossharpe1_validateoossharpe2_corr.png](attachment:Figure_2_trainoossharpe1_validateoossharpe2_corr.png)

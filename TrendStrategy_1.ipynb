# %% [markdown]
# ![Screenshot%202024-01-17%20105544.png](attachment:Screenshot%202024-01-17%20105544.png)

# %% [markdown]
# ![Screenshot%202024-01-17%20105516.png](attachment:Screenshot%202024-01-17%20105516.png)

# %% [markdown]
# optimizacijos OOS 2017-09-21

# %% [markdown]
# ![TrendStrategy_market_execution2024-01-17_11-30-12.JPG](attachment:TrendStrategy_market_execution2024-01-17_11-30-12.JPG)

# %% [markdown]
# ![TrendStrategy_market_execution_2020_2024-01-17_11-30-12.JPG](attachment:TrendStrategy_market_execution_2020_2024-01-17_11-30-12.JPG)

# %% [markdown]
# ![TrendStrategy_market_execution_2020_2024-01-18_19-41-17.JPG](attachment:TrendStrategy_market_execution_2020_2024-01-18_19-41-17.JPG)

# %% [markdown]
# ![month_compare.png](attachment:month_compare.png)

# %% [markdown]
# ![TrendStrategy_market_execution2024-01-24_09-16-34.JPG](attachment:TrendStrategy_market_execution2024-01-24_09-16-34.JPG)

# %% [markdown]
# ![TrendStrategy_market_execution_2020_2024-01-26_08-48-45.JPG](attachment:TrendStrategy_market_execution_2020_2024-01-26_08-48-45.JPG)

# %% [markdown]
# ![Figure_2_%20WF_compare.png](attachment:Figure_2_%20WF_compare.png)

# %% [markdown]
# ![TrendStrategy_market_execution_2020_2024-01-26_10-30-06.JPG](attachment:TrendStrategy_market_execution_2020_2024-01-26_10-30-06.JPG)

# %% [markdown]
# ![Figure_HM2000.png](attachment:Figure_HM2000.png)

# %% [markdown]
# ![Figure_HM2000_.png](attachment:Figure_HM2000_.png)

# %% [markdown]
# ![Figure_HM2000_2.png](attachment:Figure_HM2000_2.png)

# %% [markdown]
# ![Figure_HM2000_3.png](attachment:Figure_HM2000_3.png)

# %% [markdown]
# filtruoti

# %% [markdown]
# ![OOS_WF_1M_shr_0.62343806_export_dataframenet0.5_@ES_2023-10-02_09-58-29.jpg](attachment:OOS_WF_1M_shr_0.62343806_export_dataframenet0.5_@ES_2023-10-02_09-58-29.jpg)

# %% [markdown]
# ![comsha_shr_all_1.1254872_shr_oos_0.5797356_export_dataframenet0.5_@ES_2023-10-02_09-58-29.jpg](attachment:comsha_shr_all_1.1254872_shr_oos_0.5797356_export_dataframenet0.5_@ES_2023-10-02_09-58-29.jpg)

# %% [markdown]
# ne filtruoti

# %% [markdown]
# ![OOS_WF_1M_shr_1.4400015_export_dataframe_@ES_2023-09-29_17-05-23.jpg](attachment:OOS_WF_1M_shr_1.4400015_export_dataframe_@ES_2023-09-29_17-05-23.jpg)

# %% [markdown]
# ![comsha_shr_all_1.8341374_shr_oos_1.278848_export_dataframe_@ES_2023-09-29_17-05-23.jpg](attachment:comsha_shr_all_1.8341374_shr_oos_1.278848_export_dataframe_@ES_2023-09-29_17-05-23.jpg)

# %% [markdown]
# model train

# %% [markdown]
# ![nettrain2023-10-02_09-57-14_ALL.png](attachment:nettrain2023-10-02_09-57-14_ALL.png)

# %% [markdown]
# 1 Visi optimizacijos rezultatai suklijuoti
# 2 Modelis treniruojamas ant visu suklijuotu
#
# filename = "../export_dataframe_@ES_2023-09-29_17-05-23.csv"
# data = pd.read_csv(filename, delimiter=',', index_col=0)
#
# filename = "../export_dataframe_@TU_2023-09-30_11-12-24.csv"
# data1 = pd.read_csv(filename, delimiter=',', index_col=0)
#
# filename = "../export_dataframe_@TY_2023-09-30_10-49-47.csv"
# data2 = pd.read_csv(filename, delimiter=',', index_col=0)
#
# filename = "../export_dataframe_@US_2023-09-30_11-01-03.csv"
# data3 = pd.read_csv(filename, delimiter=',', index_col=0)
#
# result = pd.concat([data, data1, data2, data3])
# filename = "ALL"

# %% [markdown]
# failo pvz
#
#
# ,sharpe,total_trades,winning_trades,losing_trades,even_trades,win%,avg_winning_trade,avg_losing_trade,drawdown,drawdown_period,net_profit,net_loss,profit_factor,largest_winning_trade,largest_losing_trade,largest_winner_asof_total_profit,largest_loser_asof_total_loss,sortino_ratio,calmar_ratio,sharpe_oos,total_trades_oos,winning_trades_oos,losing_trades_oos,even_trades_oos,win%_oos,avg_winning_trade_oos,avg_losing_trade_oos,drawdown_oos,drawdown_period_oos,net_profit_oos,net_loss_oos,profit_factor_oos,largest_winning_trade_oos,largest_losing_trade_oos,largest_winner_asof_total_profit_oos,largest_loser_asof_total_loss_oos,sortino_ratio_oos,calmar_ratio_oos,shrp_oos1,shrp_oos2
#
# "1,6,3,1,0.18881893018095086,0.9441012203251684,4066,2.038290481483612,144WIN",0.3932349499356187,919,276,643,0,0.3003264417845484,5603.052536231884,-2111.958514743071,95991.85961933271,440,1572824.1000000006,-1291251.3249797951,1.218061944698962,28123.0,-8222.304941983903,0.017880575456594282,0.006367703004767535,0.4967437181510172,1.9625953259714104,-0.06435053313270458,253,112,141,0,0.4426877470355731,6689.107142857143,-5454.761952494801,132166.47096315637,527,754197.5999999987,-762085.035301767,0.9896501900228953,25399.2,-17377.22635464781,0.033677115917632255,0.02280221438512679,-0.0698490036827247,-0.15159998716582926,-0.23684933459691504,0.11826118323741473
#
# "1,37,4,-1,1.3602645886151719,0.5224770493066945,4665,2.2863655400785703,173WIN",0.5543616592004019,116,70,46,0,0.603448275862069,2134.785714285714,-2114.1402585582327,14807.949064031065,533,157412.20000000007,-91723.25189367871,1.7161646229296896,4198.8,-3580.2255226973025,0.026673917269436537,0.039032910944406245,0.225758800854411,3.5240901951154897,0.3035813743534639,51,39,12,0,0.7647058823529411,2167.6923076923076,-5310.622587386788,16933.11897125848,312,86460.79999999994,-63119.87104864144,1.3697873358038313,6486.3,-12795.950395743757,0.07502012472704399,0.2027245965994281,0.0858178137002418,1.2291019148146847,0.37042264317418894,0.24221436256396087
